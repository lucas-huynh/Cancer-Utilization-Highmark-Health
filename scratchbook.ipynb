# %%
import pandas as pd
import numpy as np

from IPython.display import display

# %%
staging = pd.read_csv('staging_dataset_cmu 1.csv')
claims_1 = pd.read_csv('claims_staged_cmu_1_2.csv')
claims_2 = pd.read_csv('claims_staged_cmu_2_2.csv')

# merge two claims datasets
claims = pd.concat([claims_1, claims_2], ignore_index=True)

# %% [markdown]
# # I. Staging

# %% [markdown]
# ## A. Staging Descriptive Stat

# %%
staging
# Out:
#      ICD10_CODE member_number  MOST_RECENT_PATH_STAGE_DT  \
# 0       C50.411          B908                       64.0
# 1       C50.919          B760                        NaN
# 2        C34.11          C597                        NaN
# 3       C50.519          B621                       77.0
# 4       C50.412          A392                       33.0
# ...         ...           ...                        ...
# 3762        C20          D338                        NaN
# 3763    C50.812          B004                        NaN
# 3764      C21.0          D206                        NaN
# 3765      C18.2          B320                       20.0
# 3766      C18.9          B320                       20.0
#
#       MOST_RECENT_CLINICAL_STAGE_DT PATHOLOGIC_STAGE_GROUP  \
# 0                               NaN               Stage IA
# 1                             888.0                    NaN
# 2                               0.0                    NaN
# 3                               NaN               Stage IA
# 4                               NaN               Stage IA
# ...                             ...                    ...
# 3762                        -2168.0                    NaN
# 3763                          238.0                    NaN
# 3764                           11.0                    NaN
# 3765                            NaN              Stage IVA
# 3766                            NaN              Stage IVA
#
#      CLINICAL_STAGE_GROUP
# 0                     NaN
# 1                Stage IA
# 2               Stage IVB
# 3                     NaN
# 4                     NaN
# ...                   ...
# 3762            Stage IIA
# 3763            Stage IIA
# 3764            Stage IIA
# 3765                  NaN
# 3766                  NaN
#
# [3767 rows x 6 columns]

# %%
staging.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3767 entries, 0 to 3766
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ICD10_CODE                     3767 non-null   object
#  1   member_number                  3767 non-null   object
#  2   MOST_RECENT_PATH_STAGE_DT      1913 non-null   float64
#  3   MOST_RECENT_CLINICAL_STAGE_DT  2313 non-null   float64
#  4   PATHOLOGIC_STAGE_GROUP         1853 non-null   object
#  5   CLINICAL_STAGE_GROUP           2223 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 176.7+ KB

# %%
# missing values
staging.isna().sum().sort_values(ascending=False)
# Out:
# PATHOLOGIC_STAGE_GROUP           1914
# MOST_RECENT_PATH_STAGE_DT        1854
# CLINICAL_STAGE_GROUP             1544
# MOST_RECENT_CLINICAL_STAGE_DT    1454
# ICD10_CODE                          0
# member_number                       0
# dtype: int64

# %%
# percentage missingness
((staging.isna().sum() / len(staging)) * 100).sort_values(ascending=False)
# Out:
# PATHOLOGIC_STAGE_GROUP           50.809663
# MOST_RECENT_PATH_STAGE_DT        49.216883
# CLINICAL_STAGE_GROUP             40.987523
# MOST_RECENT_CLINICAL_STAGE_DT    38.598354
# ICD10_CODE                        0.000000
# member_number                     0.000000
# dtype: float64

# %%
# number of unique values per column
print(staging.nunique()) 

'''3657 records in staging'''
'''Need to check path/clinical stages for multiple records'''
# Out:
# ICD10_CODE                         64
# member_number                    3657
# MOST_RECENT_PATH_STAGE_DT         754
# MOST_RECENT_CLINICAL_STAGE_DT     869
# PATHOLOGIC_STAGE_GROUP             20
# CLINICAL_STAGE_GROUP               21
# dtype: int64
# 'Need to check path/clinical stages for multiple records'

# %% [markdown]
# ## B. Check multiple staging records

# %%
# how many member numbers have multiple records in staging
print('Number of members with multiple records:', (staging['member_number'].value_counts() > 1).sum())

'''Among all 3,657 members, 107 of them got multiple staging records'''

# check among them, what is the distribution of records
vc = staging['member_number'].value_counts()
dup_members = vc[vc > 1].index  # member_numbers that appear more than once

# Show all columns and all rows for these members, as a full DataFrame in the notebook
display(staging[staging['member_number'].isin(dup_members)])

'''These 107 members have multiple staging records may contribute to stage and claims analysis'''

# List out these 107 members (dup_members) with their number of records
for member, count in vc[vc > 1].items():
    print(f"Member: {member} - Number of records: {count}")

'''See below for full listing of all 107 members with multiple staging records and their number of records.

Members with 3 records:
D391, C353, B102

(The rest have 2 records; full list shown below)
B320, C871, C239, A536, C555, A664, C100, C978, A233, A082, C453, D090, A380, A254, C020, D122, C859, B233, C794, C534, C440, C698, B899, C326, D471, B354, C134, A792, B091, A123, B575, C454, B248, D070, C350, D575, B201, A286, B238, C390, A065, A505, C608, A929, B641, C466, A447, B409, A956, A032, A464, D420, B696, B097, B473, D351, A124, C081, B054, D579, B311, C377, D519, A809, B926, C927, D047, A622, A643, B406, B940, A135, B373, C145, C791, C314, C186, B752, C866, A597, C090, B514, D363, B576, B172, D324, A023, B424, A759, B156, B466, C032, B845, A236, A567, C899, B402, D071, C885, A108, B154, B057, A700, A050

(Full explicit member list printed for clarity)'''
# Out:
# Number of members with multiple records: 107
#      ICD10_CODE member_number  MOST_RECENT_PATH_STAGE_DT  \
# 31       C34.32          B057                        NaN
# 32       C34.90          B057                        NaN
# 133     C50.211          A464                       61.0
# 134     C50.412          A464                       61.0
# 145      C34.11          A108                       61.0
# ...         ...           ...                        ...
# 3712    C50.912          A700                        NaN
# 3725    C50.911          A050                        NaN
# 3726    C50.912          A050                      194.0
# 3765      C18.2          B320                       20.0
# 3766      C18.9          B320                       20.0
#
#       MOST_RECENT_CLINICAL_STAGE_DT PATHOLOGIC_STAGE_GROUP  \
# 31                           1242.0                    NaN
# 32                            840.0                    NaN
# 133                             NaN               Stage IA
# 134                             NaN               Stage IA
# 145                            28.0             Stage IIIA
# ...                             ...                    ...
# 3712                          992.0                    NaN
# 3725                           21.0                    NaN
# 3726                            NaN               Stage IA
# 3765                            NaN              Stage IVA
# 3766                            NaN              Stage IVA
#
#      CLINICAL_STAGE_GROUP
# 31              Stage IA3
# 32              Stage IIB
# 133                   NaN
# 134                   NaN
# 145            Stage IIIA
# ...                   ...
# 3712             Stage IA
# 3725             Stage IA
# 3726                  NaN
# 3765                  NaN
# 3766                  NaN
#
# [217 rows x 6 columns]
# Member: D391 - Number of records: 3
# Member: C353 - Number of records: 3
# Member: B102 - Number of records: 3
# Member: B320 - Number of records: 2
# Member: C871 - Number of records: 2
# Member: C239 - Number of records: 2
# Member: A536 - Number of records: 2
# Member: C555 - Number of records: 2
# Member: A664 - Number of records: 2
# Member: C100 - Number of records: 2
# Member: C978 - Number of records: 2
# Member: A233 - Number of records: 2
# Member: A082 - Number of records: 2
# Member: C453 - Number of records: 2
# Member: D090 - Number of records: 2
# Member: A380 - Number of records: 2
# Member: A254 - Number of records: 2
# Member: C020 - Number of records: 2
# Member: D122 - Number of records: 2
# Member: C859 - Number of records: 2
# Member: B233 - Number of records: 2
# Member: C794 - Number of records: 2
# Member: C534 - Number of records: 2
# Member: C440 - Number of records: 2
# Member: C698 - Number of records: 2
# Member: B899 - Number of records: 2
# Member: C326 - Number of records: 2
# Member: D471 - Number of records: 2
# Member: B354 - Number of records: 2
# Member: C134 - Number of records: 2
# Member: A792 - Number of records: 2
# Member: B091 - Number of records: 2
# Member: A123 - Number of records: 2
# Member: B575 - Number of records: 2
# Member: C454 - Number of records: 2
# Member: B248 - Number of records: 2
# Member: D070 - Number of records: 2
# Member: C350 - Number of records: 2
# Member: D575 - Number of records: 2
# Member: B201 - Number of records: 2
# Member: A286 - Number of records: 2
# Member: B238 - Number of records: 2
# Member: C390 - Number of records: 2
# Member: A065 - Number of records: 2
# Member: A505 - Number of records: 2
# Member: C608 - Number of records: 2
# Member: A929 - Number of records: 2
# Member: B641 - Number of records: 2
# Member: C466 - Number of records: 2
# Member: A447 - Number of records: 2
# Member: B409 - Number of records: 2
# Member: A956 - Number of records: 2
# Member: A032 - Number of records: 2
# Member: A464 - Number of records: 2
# Member: D420 - Number of records: 2
# Member: B696 - Number of records: 2
# Member: B097 - Number of records: 2
# Member: B473 - Number of records: 2
# Member: D351 - Number of records: 2
# Member: A124 - Number of records: 2
# Member: C081 - Number of records: 2
# Member: B054 - Number of records: 2
# Member: D579 - Number of records: 2
# Member: B311 - Number of records: 2
# Member: C377 - Number of records: 2
# Member: D519 - Number of records: 2
# Member: A809 - Number of records: 2
# Member: B926 - Number of records: 2
# Member: C927 - Number of records: 2
# Member: D047 - Number of records: 2
# Member: A622 - Number of records: 2
# Member: A643 - Number of records: 2
# Member: B406 - Number of records: 2
# Member: B940 - Number of records: 2
# Member: A135 - Number of records: 2
# Member: B373 - Number of records: 2
# Member: C145 - Number of records: 2
# Member: C791 - Number of records: 2
# Member: C314 - Number of records: 2
# Member: C186 - Number of records: 2
# Member: B752 - Number of records: 2
# Member: C866 - Number of records: 2
# Member: A597 - Number of records: 2
# Member: C090 - Number of records: 2
# Member: B514 - Number of records: 2
# Member: D363 - Number of records: 2
# Member: B576 - Number of records: 2
# Member: B172 - Number of records: 2
# Member: D324 - Number of records: 2
# Member: A023 - Number of records: 2
# Member: B424 - Number of records: 2
# Member: A759 - Number of records: 2
# Member: B156 - Number of records: 2
# Member: B466 - Number of records: 2
# Member: C032 - Number of records: 2
# Member: B845 - Number of records: 2
# Member: A236 - Number of records: 2
# Member: A567 - Number of records: 2
# Member: C899 - Number of records: 2
# Member: B402 - Number of records: 2
# Member: D071 - Number of records: 2
# Member: C885 - Number of records: 2
# Member: A108 - Number of records: 2
# Member: B154 - Number of records: 2
# Member: B057 - Number of records: 2
# Member: A700 - Number of records: 2
# Member: A050 - Number of records: 2
# 'See below for full listing of all 107 members with multiple staging records and their number of records.\n\nMembers with 3 records:\nD391, C353, B102\n\n(The rest have 2 records; full list shown below)\nB320, C871, C239, A536, C555, A664, C100, C978, A233, A082, C453, D090, A380, A254, C020, D122, C859, B233, C794, C534, C440, C698, B899, C326, D471, B354, C134, A792, B091, A123, B575, C454, B248, D070, C350, D575, B201, A286, B238, C390, A065, A505, C608, A929, B641, C466, A447, B409, A956, A032, A464, D420, B696, B097, B473, D351, A124, C081, B054, D579, B311, C377, D519, A809, B926, C927, D047, A622, A643, B406, B940, A135, B373, C145, C791, C314, C186, B752, C866, A597, C090, B514, D363, B576, B172, D324, A023, B424, A759, B156, B466, C032, B845, A236, A567, C899, B402, D071, C885, A108, B154, B057, A700, A050\n\n(Full explicit member list printed for audit and clarity)'

# %%
# # Take a look at member D391, C353, C102
# display(staging[staging['member_number'].isin(['D391', 'C353', 'B102'])])

# There 3 members with multiple records in staging, two of them have more than one cancer type

# %%
# how many member numbers have exactly 1 record in staging
print('Number of members with exactly 1 record:', (staging['member_number'].value_counts() == 1).sum())

# verify total number of unique members: (members with exactly 1 record) + (members with >1 record)
print('Total number of unique members:', (staging['member_number'].value_counts() == 1).sum() + (staging['member_number'].value_counts() > 1).sum())
# Out:
# Number of members with exactly 1 record: 3550
# Total number of unique members: 3657

# %%
# # unique values per column and count of each
# for column in staging.columns:
#         print(f"Column: {column}")
#         print(staging[column].value_counts())
#         print("\n")

# %% [markdown]
# ## C. Mapping ICD10 to cancers

# %%
# group by first 3 characters of ICD10 code and count occurrences
staging['ICD10_group'] = staging['ICD10_CODE'].str[:3]
icd10_group_counts = staging['ICD10_group'].value_counts()
print(icd10_group_counts)
print(icd10_group_counts.sum()) # number of records in staging

'''
Clarification: 
Number of records (3767) - numbers of unique members (3657) = 110, but why is that members with multiple records is 107?
A: 107 unique members who have multiple records have 110 staging records
'''
# Out:
# ICD10_group
# C50    2300
# C34     715
# C18     501
# C20     171
# C21      55
# C19      25
# Name: count, dtype: int64
# 3767
# '\nClarification: \nNumber of records (3767) - numbers of unique members (3657) = 110, but why is that members with multiple records is 107?\nA: 107 unique members who have multiple records have 110 staging records\n'

# %%
# detailed mapping of ICD10 codes to cancer types
detailed_cancer_map = {
    "C50": "breast",
    "C34": "lung",
    "C18": "colon",
    "C19": "rectal",      # rectosigmoid
    "C20": "rectal",      # rectum
    "C21": "anal"         # anus (or keep as colorectal)
}

'''
treatments for colon and rectal cancers are different, so we create a new column for detailed cancer type
'''

staging['detailed_cancer_type'] = staging['ICD10_group'].map(detailed_cancer_map)

# creating a new column for cancer type, C18, C19, C20, C21 are all colorectal
broad_cancer_map = {
    "C50": "breast",
    "C34": "lung",
    "C18": "colorectal",
    "C19": "colorectal",
    "C20": "colorectal",
    "C21": "colorectal"
}
staging['cancer_type'] = staging['ICD10_group'].map(broad_cancer_map)

# %%
staging.head()
# Out:
#   ICD10_CODE member_number  MOST_RECENT_PATH_STAGE_DT  \
# 0    C50.411          B908                       64.0
# 1    C50.919          B760                        NaN
# 2     C34.11          C597                        NaN
# 3    C50.519          B621                       77.0
# 4    C50.412          A392                       33.0
#
#    MOST_RECENT_CLINICAL_STAGE_DT PATHOLOGIC_STAGE_GROUP CLINICAL_STAGE_GROUP  \
# 0                            NaN               Stage IA                  NaN
# 1                          888.0                    NaN             Stage IA
# 2                            0.0                    NaN            Stage IVB
# 3                            NaN               Stage IA                  NaN
# 4                            NaN               Stage IA                  NaN
#
#   ICD10_group detailed_cancer_type cancer_type
# 0         C50               breast      breast
# 1         C50               breast      breast
# 2         C34                 lung        lung
# 3         C50               breast      breast
# 4         C50               breast      breast

# %% [markdown]
# ## D. Explore dt and path & clinical staging

# %%
# summary statistics for numeric columns
staging.describe() # what does negative path stage mean?


# 0: member's first cancer-related diagnosis
# Out:
#        MOST_RECENT_PATH_STAGE_DT  MOST_RECENT_CLINICAL_STAGE_DT
# count                1913.000000                    2313.000000
# mean                  112.602196                     133.441418
# std                   679.544573                     650.934610
# min                 -3089.000000                   -3106.000000
# 25%                    23.000000                       0.000000
# 50%                    54.000000                      32.000000
# 75%                   152.000000                     153.000000
# max                  3482.000000                    3613.000000

# %%
# crosstab of pathologic and clinical staging
staging["has_path"] = staging["PATHOLOGIC_STAGE_GROUP"].notna()
staging["has_clin"] = staging["CLINICAL_STAGE_GROUP"].notna()

pd.crosstab(staging["has_path"], staging["has_clin"])
# Out:
# has_clin  False  True
# has_path
# False         0   1914
# True       1544    309

# %%
# verify that sum of crosstab is equal to number of numbers of staging records
crosstab_counts = pd.crosstab(staging["has_path"], staging["has_clin"])
display(crosstab_counts)
total = crosstab_counts.values.sum()
print('Sum of all 4 cells:', total)
# Out:
# has_clin  False  True
# has_path
# False         0   1914
# True       1544    309
# Sum of all 4 cells: 3767

# %%
# show patients with both pathological and clinical staging
both = staging[
    staging["PATHOLOGIC_STAGE_GROUP"].notna() &
    staging["CLINICAL_STAGE_GROUP"].notna()
].copy()

# %%
# check for members with both path and clin staging and if their stages match
both["stages_match"] = (
    both["PATHOLOGIC_STAGE_GROUP"].str.strip() ==
    both["CLINICAL_STAGE_GROUP"].str.strip()
)

both["stages_match"].value_counts() # count of matches
# Out:
# stages_match
# False    212
# True      97
# Name: count, dtype: int64

# %%
# create a new column for final stage 
staging["FINAL_STAGE"] = (
    staging["CLINICAL_STAGE_GROUP"]
    .combine_first(staging["PATHOLOGIC_STAGE_GROUP"])
)

# Highmark prefers clinical staging over pathologic staging

# %%
# group by pathologic stage group
# staging.groupby('PATHOLOGIC_STAGE_GROUP').describe()['MOST_RECENT_PATH_STAGE_DT']
# Out:
#                          count     mean      std       min      25%     50%  \
# PATHOLOGIC_STAGE_GROUP
# No Stage Recommended   121.000   88.504  556.996 -2160.000   81.000 200.000
# Stage 0                  8.000 -214.750  711.306 -1940.000  -68.000  24.000
# Stage I                 54.000  114.778  565.717 -2336.000   14.250  34.000
# Stage IA               922.000   88.190  644.076 -3089.000   27.000  50.000
# Stage IA1                5.000  258.000 1370.922 -1237.000    0.000   0.000
# Stage IA2               28.000  218.607  845.347 -1198.000    0.000  38.500
# Stage IA3               12.000  156.417  659.255  -662.000  -60.750  26.500
# Stage IB               177.000  167.989  761.972 -2402.000   26.000  65.000
# Stage II                 1.000    0.000      NaN     0.000    0.000   0.000
# Stage IIA              168.000   31.524  807.642 -2900.000    6.000  41.000
# Stage IIB               72.000  102.542  668.941 -2256.000   22.250  63.500
# Stage IIC                3.000 -530.333 1029.455 -1719.000 -832.000  55.000
# Stage IIIA              66.000  105.576  846.375 -3039.000   15.750  52.500
# Stage IIIB             106.000   24.066  511.838 -1779.000    7.500  38.500
# Stage IIIC              27.000   78.667  310.916  -763.000   23.000  41.000
# Stage IV                26.000  664.654  992.720 -1857.000   70.000 550.000
# Stage IVA               27.000  484.852  702.446     4.000   39.500 220.000
# Stage IVB                9.000  315.444  284.033     0.000   77.000 299.000
# Stage IVC                7.000  182.286  335.564     1.000   17.500  49.000
# Stage Unknown           14.000  233.071  475.804  -624.000   29.250  95.500
#
#                             75%      max
# PATHOLOGIC_STAGE_GROUP
# No Stage Recommended    244.000 2184.000
# Stage 0                 110.750  181.000
# Stage I                  88.750 2606.000
# Stage IA                 88.000 3456.000
# Stage IA1                13.000 2514.000
# Stage IA2                96.000 2877.000
# Stage IA3                63.500 1698.000
# Stage IB                112.000 2919.000
# Stage II                  0.000    0.000
# Stage IIA               103.250 3454.000
# Stage IIB               198.250 2163.000
# Stage IIC                64.000   73.000
# Stage IIIA              208.750 3260.000
# Stage IIIB               76.000 2601.000
# Stage IIIC              183.000  659.000
# Stage IV               1217.250 3482.000
# Stage IVA               576.500 3026.000
# Stage IVB               470.000  714.000
# Stage IVC               133.000  925.000
# Stage Unknown           584.500 1003.000

# %%
# group by clinical stage group
# staging.groupby('CLINICAL_STAGE_GROUP').describe()['MOST_RECENT_CLINICAL_STAGE_DT']
# Out:
#                        count     mean     std       min      25%      50%  \
# CLINICAL_STAGE_GROUP
# No Stage Recommended  16.000  391.562 698.719 -1131.000  116.250  173.000
# Occult carcinoma       1.000 -559.000     NaN  -559.000 -559.000 -559.000
# Stage 0               14.000  179.571 324.542   -35.000   -8.000    9.500
# Stage I               51.000  296.549 563.263  -458.000   30.500   77.000
# Stage IA             392.000  154.661 682.418 -2906.000   13.750   54.500
# Stage IA1             30.000   89.733 498.851 -1525.000    0.000    0.000
# Stage IA2            108.000  272.463 750.784 -1104.000    0.000    0.000
# Stage IA3             48.000   22.833 540.157 -1500.000   -0.250    7.500
# Stage IB             190.000    4.053 589.260 -2416.000    0.000   22.000
# Stage II               3.000   -1.000  17.521   -19.000   -9.500    0.000
# Stage IIA            275.000  137.487 740.618 -3106.000    7.000   46.000
# Stage IIB            213.000    3.915 534.590 -2105.000    0.000   18.000
# Stage IIC              5.000  454.000 620.715     0.000    2.000   13.000
# Stage IIIA           147.000  110.170 478.070 -1616.000    0.000   28.000
# Stage IIIB           266.000   77.673 643.903 -2349.000    3.250   22.000
# Stage IIIC            80.000   77.775 380.768  -546.000    0.750   16.000
# Stage IV             177.000  391.932 840.985 -2298.000   10.000   67.000
# Stage IVA             99.000  152.535 668.139 -2147.000    0.000   16.000
# Stage IVB             77.000  167.974 539.706 -1902.000    1.000   15.000
# Stage IVC             20.000  520.300 821.021  -816.000   15.750  127.000
# Stage Unknown         11.000  122.818 688.372  -583.000 -212.000    3.000
#
#                           75%      max
# CLINICAL_STAGE_GROUP
# No Stage Recommended  781.250 2066.000
# Occult carcinoma     -559.000 -559.000
# Stage 0               289.000  931.000
# Stage I               236.500 2912.000
# Stage IA              331.750 3320.000
# Stage IA1             385.250 1028.000
# Stage IA2              83.000 3171.000
# Stage IA3              46.750 1826.000
# Stage IB               58.000 2940.000
# Stage II                8.000   16.000
# Stage IIA             308.500 3243.000
# Stage IIB              66.000 2709.000
# Stage IIC            1007.000 1248.000
# Stage IIIA            162.500 2388.000
# Stage IIIB             69.000 3223.000
# Stage IIIC             48.250 2560.000
# Stage IV              635.000 3613.000
# Stage IVA             142.000 2206.000
# Stage IVB              91.000 2209.000
# Stage IVC             916.500 2368.000
# Stage Unknown         149.000 1966.000

# %%
# number of unique members per final stage group
staging.groupby("FINAL_STAGE")["member_number"].nunique().sort_values(ascending=False)
# Out:
# FINAL_STAGE
# Stage IA                1217
# Stage IIA                414
# Stage IIIB               358
# Stage IB                 343
# Stage IIB                269
# Stage IV                 195
# Stage IIIA               192
# Stage IA2                130
# Stage IVA                121
# Stage IIIC               104
# Stage I                  100
# Stage IVB                 82
# Stage IA3                 56
# No Stage Recommended      52
# Stage IA1                 34
# Stage IVC                 26
# Stage 0                   19
# Stage Unknown             11
# Stage IIC                  8
# Stage II                   3
# Occult carcinoma           1
# Name: member_number, dtype: int64

# %%
staging.head()
# Out:
#   ICD10_CODE member_number  MOST_RECENT_PATH_STAGE_DT  \
# 0    C50.411          B908                       64.0
# 1    C50.919          B760                        NaN
# 2     C34.11          C597                        NaN
# 3    C50.519          B621                       77.0
# 4    C50.412          A392                       33.0
#
#    MOST_RECENT_CLINICAL_STAGE_DT PATHOLOGIC_STAGE_GROUP CLINICAL_STAGE_GROUP  \
# 0                            NaN               Stage IA                  NaN
# 1                          888.0                    NaN             Stage IA
# 2                            0.0                    NaN            Stage IVB
# 3                            NaN               Stage IA                  NaN
# 4                            NaN               Stage IA                  NaN
#
#   ICD10_group detailed_cancer_type cancer_type  has_path  has_clin FINAL_STAGE
# 0         C50               breast      breast      True     False    Stage IA
# 1         C50               breast      breast     False      True    Stage IA
# 2         C34                 lung        lung     False      True   Stage IVB
# 3         C50               breast      breast      True     False    Stage IA
# 4         C50               breast      breast      True     False    Stage IA

# %% [markdown]
# ### Decide how to drop members
# Current: drop all 107 member (dup_member: those have > 1 staging records) with 110 staging records
# -> may drop members with only one cancer and its stage update
#
# OR
#
# Alternaitve: drop dup_member who have > 1 cancer type

# %%
# drop staging rows with multiple records per member number 
multi_records_members = staging["member_number"].value_counts()
multi_records_members = multi_records_members[multi_records_members > 1].index

staging = staging[~staging["member_number"].isin(multi_records_members)]
print('Number of unique members after dropping dup_member with multiple records:', len(staging))
# Out:
# Number of unique members after dropping dup_member with multiple records: 3550

# %%
# drop dup_member who have > 1 cancer type
multi_cancer_members = staging.groupby("member_number")["cancer_type"].nunique()
multi_cancer_members = multi_cancer_members[multi_cancer_members > 1].index

staging = staging[~staging["member_number"].isin(multi_cancer_members)]

print('Number of unique members after dropping dup_member with multiple cancer types:', len(staging))


# confirm again
# Out:
# Number of unique members after dropping dup_member with multiple cancer types: 3703

# %% [markdown]
# ### Claims

# %%
claims
# Out:
#         PRI_DIAG_CD ADM_DIAG_CD DIAG_CD_001 DIAG_CD_002 DIAG_CD_003  HCPCS  \
# 0              J431         NaN         NaN         NaN         NaN  94727
# 1              J431         NaN         NaN         NaN         NaN  94060
# 2              J431         NaN         NaN         NaN         NaN  94060
# 3              J431         NaN         NaN         NaN         NaN  94726
# 4              J431         NaN         NaN         NaN         NaN  94729
# ...             ...         ...         ...         ...         ...    ...
# 2517382      C50411         NaN        Z170       E1165        Z794  83036
# 2517383      C50411         NaN        Z170       E1165        Z794  82607
# 2517384      C50411         NaN        Z170       E1165        Z794  80061
# 2517385      C50411         NaN        Z170       E1165        Z794  85025
# 2517386      C50411         NaN        Z170       E1165        Z794  81003
#
#          DRG    Med_Cost_Category NDC_CD DRUG_NM  ...  provider_number  \
# 0        NaN  Prof PCP Procedures    NaN     NaN  ...              NaN
# 1        NaN  Prof PCP Procedures    NaN     NaN  ...              NaN
# 2        NaN             OP Other    NaN     NaN  ...         2236.000
# 3        NaN             OP Other    NaN     NaN  ...         2236.000
# 4        NaN             OP Other    NaN     NaN  ...         2236.000
# ...      ...                  ...    ...     ...  ...              ...
# 2517382  NaN          OP Path/Lab    NaN     NaN  ...         8094.000
# 2517383  NaN          OP Path/Lab    NaN     NaN  ...         8094.000
# 2517384  NaN          OP Path/Lab    NaN     NaN  ...         8094.000
# 2517385  NaN          OP Path/Lab    NaN     NaN  ...         8094.000
# 2517386  NaN          OP Path/Lab    NaN     NaN  ...         8094.000
#
#          ROUTE DESCRIPTION  STRENGTH DESCRIPTION  \
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
# ...                    ...                   ...
# 2517382                NaN                   NaN
# 2517383                NaN                   NaN
# 2517384                NaN                   NaN
# 2517385                NaN                   NaN
# 2517386                NaN                   NaN
#
#                             PROC_DESC  \
# 0           Pulm function test by gas
# 1              Evaluation of wheezing
# 2              Evaluation of wheezing
# 3        Pulm funct tst plethysmograp
# 4         Co/membane diffuse capacity
# ...                               ...
# 2517382  Glycosylated hemoglobin test
# 2517383                  Vitamin B-12
# 2517384                   Lipid panel
# 2517385  Complete cbc w/auto diff wbc
# 2517386     Urinalysis auto w/o scope
#
#                                                  DIAG_DESC DRG_DESC  \
# 0                                     Panlobular emphysema      NaN
# 1                                     Panlobular emphysema      NaN
# 2                                     Panlobular emphysema      NaN
# 3                                     Panlobular emphysema      NaN
# 4                                     Panlobular emphysema      NaN
# ...                                                    ...      ...
# 2517382  Malig neoplm of upper-outer quadrant of right ...      NaN
# 2517383  Malig neoplm of upper-outer quadrant of right ...      NaN
# 2517384  Malig neoplm of upper-outer quadrant of right ...      NaN
# 2517385  Malig neoplm of upper-outer quadrant of right ...      NaN
# 2517386  Malig neoplm of upper-outer quadrant of right ...      NaN
#
#         ADM_DIAG_DESC                       DIAG_001_DIAG_DESC  \
# 0                 NaN                                      NaN
# 1                 NaN                                      NaN
# 2                 NaN                                      NaN
# 3                 NaN                                      NaN
# 4                 NaN                                      NaN
# ...               ...                                      ...
# 2517382           NaN  Estrogen receptor positive status [ER+]
# 2517383           NaN  Estrogen receptor positive status [ER+]
# 2517384           NaN  Estrogen receptor positive status [ER+]
# 2517385           NaN  Estrogen receptor positive status [ER+]
# 2517386           NaN  Estrogen receptor positive status [ER+]
#
#                                   DIAG_002_DIAG_DESC  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 2517382  Type 2 diabetes mellitus with hyperglycemia
# 2517383  Type 2 diabetes mellitus with hyperglycemia
# 2517384  Type 2 diabetes mellitus with hyperglycemia
# 2517385  Type 2 diabetes mellitus with hyperglycemia
# 2517386  Type 2 diabetes mellitus with hyperglycemia
#
#                          DIAG_003_DIAG_DESC
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 2517382  Long term (current) use of insulin
# 2517383  Long term (current) use of insulin
# 2517384  Long term (current) use of insulin
# 2517385  Long term (current) use of insulin
# 2517386  Long term (current) use of insulin
#
# [2517387 rows x 24 columns]

# %%
claims.isna().sum().sort_values(ascending=False)
# Out:
# DRG_DESC                  2512525
# DRG                       2512496
# ADM_DIAG_DESC             2507683
# ADM_DIAG_CD               2507535
# STRENGTH DESCRIPTION      1785960
# ROUTE DESCRIPTION         1785960
# NDC_CD                    1753429
# DRUG_NM                   1752403
# DIAG_003_DIAG_DESC        1680037
# DIAG_CD_003               1662254
# DIAG_002_DIAG_DESC        1432755
# DIAG_CD_002               1408647
# DIAG_001_DIAG_DESC        1047844
# DIAG_CD_001               1022916
# provider_number            868329
# PROC_DESC                  577304
# HCPCS                      522687
# DIAG_DESC                  384833
# PRI_DIAG_CD                354145
# member_number                   0
# c_allowed                       0
# C_UTIL_CT                       0
# Med_Cost_Category               0
# days_since_earliest_dt          0
# dtype: int64

# %%
# percentage missingness
((claims.isna().sum() / len(claims)) * 100).sort_values(ascending=False)
# Out:
# DRG_DESC                 99.807
# DRG                      99.806
# ADM_DIAG_DESC            99.615
# ADM_DIAG_CD              99.609
# STRENGTH DESCRIPTION     70.945
# ROUTE DESCRIPTION        70.945
# NDC_CD                   69.653
# DRUG_NM                  69.612
# DIAG_003_DIAG_DESC       66.737
# DIAG_CD_003              66.031
# DIAG_002_DIAG_DESC       56.914
# DIAG_CD_002              55.957
# DIAG_001_DIAG_DESC       41.624
# DIAG_CD_001              40.634
# provider_number          34.493
# PROC_DESC                22.933
# HCPCS                    20.763
# DIAG_DESC                15.287
# PRI_DIAG_CD              14.068
# member_number             0.000
# c_allowed                 0.000
# C_UTIL_CT                 0.000
# Med_Cost_Category         0.000
# days_since_earliest_dt    0.000
# dtype: float64

# %%
claims.nunique().sort_values(ascending=False)
# Out:
# c_allowed                 436381
# C_UTIL_CT                  19728
# NDC_CD                     18608
# PRI_DIAG_CD                 9637
# DIAG_DESC                   9191
# DIAG_CD_001                 8515
# provider_number             8220
# DIAG_001_DIAG_DESC          8073
# DIAG_CD_002                 7244
# DIAG_002_DIAG_DESC          6874
# DIAG_CD_003                 6030
# HCPCS                       5955
# DIAG_003_DIAG_DESC          5715
# PROC_DESC                   4796
# days_since_earliest_dt      4051
# member_number               3657
# DRUG_NM                     1742
# ADM_DIAG_CD                 1183
# STRENGTH DESCRIPTION        1142
# ADM_DIAG_DESC               1138
# DRG                          486
# DRG_DESC                     478
# ROUTE DESCRIPTION             30
# Med_Cost_Category             20
# dtype: int64

# %%
for column in claims.columns:
        print(f"Column: {column}")
        print(claims[column].value_counts())
        print("\n")
# Out:
# Column: PRI_DIAG_CD
# Z5111      270903
# C50412      45262
# C50411      44235
# C50912      43217
# C50911      41851
#             ...
# S22028A         1
# S42121D         1
# S37812A         1
# Q279            1
# S12101D         1
# Name: PRI_DIAG_CD, Length: 9637, dtype: int64
#
#
# Column: ADM_DIAG_CD
# M6281      476
# C189       339
# S52501D    257
# G9340      192
# Z48815     179
#           ...
# I4821        1
# C049         1
# B999         1
# G720         1
# S129XXA      1
# Name: ADM_DIAG_CD, Length: 1183, dtype: int64
#
#
# Column: DIAG_CD_001
# Z170       121912
# I10         36208
# C20         29603
# Z171        27399
# C50411      26684
#             ...
# D3002           1
# S62304D         1
# M25342          1
# T498X5A         1
# T560X1S         1
# Name: DIAG_CD_001, Length: 8515, dtype: int64
#
#
# Column: DIAG_CD_002
# R112       112390
# Z170        90746
# I10         37726
# Z171        36835
# C787        21763
#             ...
# M21921          1
# L651            1
# Z83711          1
# A609            1
# S92155A         1
# Name: DIAG_CD_002, Length: 7244, dtype: int64
#
#
# Column: DIAG_CD_003
# R112       84552
# T451X5A    54012
# D701       44784
# I10        31860
# Z170       22385
#            ...
# M13859         1
# H4010X2        1
# Z1635          1
# E3123          1
# T560X1S        1
# Name: DIAG_CD_003, Length: 6030, dtype: int64
#
#
# Column: HCPCS
# 85025    82420
# 36415    76227
# 80053    74048
# 99214    73522
# 99213    53223
#          ...
# 11308        1
# L5668        1
# L5987        1
# L5681        1
# 76821        1
# Name: HCPCS, Length: 5955, dtype: int64
#
#
# Column: DRG
# 330.000    296
# 331.000    276
# 164.000    171
# 165.000    136
# 329.000    112
#           ...
# 923.000      1
# 251.000      1
# 69.000       1
# 887.000      1
# 776.000      1
# Name: DRG, Length: 486, dtype: int64
#
#
# Column: Med_Cost_Category
# Prof Specialist Procedures        570657
# RX                                445110
# OP Path/Lab                       384569
# OP Pharmacy                       271321
# OP Surgery                        176658
# Prof Invisible Prov Procedures    147399
# OP Other                          121456
# Prof PCP Procedures               109842
# OP Radiology                       87552
# OP Observation                     53689
# OP ER                              51571
# Prof Other                         50027
# PDN/Home Health                    42115
# IP Medical                          2145
# IP Surgical                         2143
# IP SNF                               524
# OP Behavioral Health                 494
# IP Behavioral Health                  82
# IP Maternity                          32
# Unknown                                1
# Name: Med_Cost_Category, dtype: int64
#
#
# Column: NDC_CD
# 00264-7800-20    6924
# 00338-0049-02    6001
# 16729-0035-10    5821
# 16729-0035-16    5593
# 00338-0049-04    4895
#                  ...
# 00088-1208-06       1
# 42571-0375-30       1
# 00904-5823-60       1
# 70461-0319-04       1
# 04928-1125-65       1
# Name: NDC_CD, Length: 18608, dtype: int64
#
#
# Column: DRUG_NM
#                                   319998
# ANASTROZOLE                        17867
# LEVOTHYROXINE SODIUM               13696
# ATORVASTATIN CALCIUM               13657
# AMLODIPINE BESYLATE                 9274
#                                    ...
# AUROVELA                               1
# NOVOLOG PENFILL                        1
# ROZEREM                                1
# MEFLOQUINE HCL                         1
# LEVOTHYROXINE SODIUM   50 MCG          1
# Name: DRUG_NM, Length: 1742, dtype: int64
#
#
# Column: C_UTIL_CT
# 0.000      857056
# 1.000      718664
# 30.000     117682
# 90.000      68619
# 2.000        9506
#             ...
# 75.014          1
# 31.095          1
# 1.085           1
# 100.006         1
# 21.046          1
# Name: C_UTIL_CT, Length: 19728, dtype: int64
#
#
# Column: c_allowed
# 0.000      539007
# 10.000       9559
# 75.000       6023
# 3.000        5639
# 7.500        4770
#             ...
# 161.646         1
# 63.232          1
# 38.167          1
# 77.410          1
# 4.057           1
# Name: c_allowed, Length: 436381, dtype: int64
#
#
# Column: days_since_earliest_dt
# 0       38059
# 28       6916
# 21       6501
# 35       6096
# 42       5982
#         ...
# 3682        1
# 3663        1
# 3659        1
# 3655        1
# 3662        1
# Name: days_since_earliest_dt, Length: 4051, dtype: int64
#
#
# Column: member_number
# A045    4371
# A372    4008
# D493    3834
# A518    3754
# D009    3732
#         ...
# D596       6
# B136       6
# B279       6
# A754       5
# C753       3
# Name: member_number, Length: 3657, dtype: int64
#
#
# Column: provider_number
# 2244.000    358229
# 2236.000    160962
# 2281.000     87753
# 2223.000     80198
# 2283.000     64766
#              ...
# 6099.000         1
# 5979.000         1
# 5930.000         1
# 4722.000         1
# 2931.000         1
# Name: provider_number, Length: 8220, dtype: int64
#
#
# Column: ROUTE DESCRIPTION
# ORAL                382352
# INTRAVENOUS         163836
# INJECTION           101280
# SUBCUTANEOUS         21614
# INHALATION           15622
# INTRAMUSCULAR        13517
# TOPICAL               8849
# OPHTHALMIC (EYE)      7412
# MISCELLANEOUS         5249
# NASAL                 3558
# TRANSDERMAL           2239
# MUCOUS MEMBRANE       1143
# INTRAOCULAR            939
# VAGINAL                831
# SUBLINGUAL             801
# IRRIGATION             654
# INTRAARTICULAR         436
# DENTAL                 321
# OTIC (EAR)             235
# RECTAL                 167
# BUCCAL                 102
# INTRADERMAL             72
# INTRAVESICAL            66
# INTRATHECAL             58
# INTRAUTERINE            41
# IMPLANTATION            16
# URETHRAL                 9
# EPIDURAL                 5
# TRANSLINGUAL             2
# INTRACAVERNOSAL          1
# Name: ROUTE DESCRIPTION, dtype: int64
#
#
# Column: STRENGTH DESCRIPTION
# 0.9 %         46035
# 20 MG         36538
# 10 MG         34779
# 5 MG          27007
# 40 MG         26724
#               ...
# 96 MG/0.27        1
# 3 %-5 %           1
# 1000MG/8ML        1
# 100 MCG/10        1
# 68 MG             1
# Name: STRENGTH DESCRIPTION, Length: 1142, dtype: int64
#
#
# Column: PROC_DESC
# Office/outpatient visit est     150386
# Complete cbc w/auto diff wbc     82420
# Routine venipuncture             76227
# Comprehen metabolic panel        74048
# Hospital outpt clinic visit      39352
#                                  ...
# Digoxin injection                    1
# Hysteroscopy dx sep proc             1
# Oral prescription drug chemo         1
# Pancreas surgery procedure           1
# Middle cerebral artery echo          1
# Name: PROC_DESC, Length: 4796, dtype: int64
#
#
# Column: DIAG_DESC
# Encounter for antineoplastic chemotherapy                       270903
# Malig neoplasm of upper-outer quadrant of left female breast     45262
# Malig neoplm of upper-outer quadrant of right female breast      44235
# Malignant neoplasm of unspecified site of left female breast     43217
# Malignant neoplasm of unsp site of right female breast           41851
#                                                                  ...
# Other infective bursitis, unspecified elbow                          1
# Oth fracture of unsp lower leg, subs for clos fx w nonunion          1
# Inj right innominate or subclavian artery, subs encntr               1
# Goniosynechiae, left eye                                             1
# Unsp nondisp fx of 2nd cervcal vert, 7thD                            1
# Name: DIAG_DESC, Length: 9191, dtype: int64
#
#
# Column: DRG_DESC
# Major small & large bowel procedures w CC                        296
# Major small & large bowel procedures w/o CC/MCC                  276
# Major chest procedures w CC                                      171
# Major chest procedures w/o CC/MCC                                136
# Major small & large bowel procedures w MCC                       112
#                                                                 ...
# Perc cardiovasc proc w/o coronary artery stent w/o MCC             1
# Transient Ischemia w/o Thrombolytic                                1
# Other mental disorder diagnoses                                    1
# Uterine & adnexa proc for ovarian or adnexal malignancy w MCC      1
# Postpartum & post abortion diagnoses w/o O.R. procedure            1
# Name: DRG_DESC, Length: 478, dtype: int64
#
#
# Column: ADM_DIAG_DESC
# Muscle weakness (generalized)                                   476
# Malignant neoplasm of colon, unspecified                        339
# Unsp fx the lower end r rad, subs for clos fx w routn heal      257
# Encephalopathy, unspecified                                     192
# Encntr for surgical aftcr following surgery on the dgstv sys    179
#                                                                ...
# Malignant neoplasm of esophagus, unspecified                      1
# Cutaneous abscess of groin                                        1
# Mech compl of cardiac electrode, initial encounter                1
# Malignant neoplasm of floor of mouth, unspecified                 1
# Fracture of neck, unspecified, initial encounter                  1
# Name: ADM_DIAG_DESC, Length: 1138, dtype: int64
#
#
# Column: DIAG_001_DIAG_DESC
# Estrogen receptor positive status [ER+]                         121912
# Essential (primary) hypertension                                 36208
# Malignant neoplasm of rectum                                     29603
# Estrogen receptor negative status [ER-]                          27399
# Malig neoplm of upper-outer quadrant of right female breast      26684
#                                                                  ...
# Hepatorenal syndrome                                                 1
# Other instability, left hand                                         1
# Unsp fx fourth MC bone, right hand, subs for fx w routn heal         1
# Benign neoplasm of left kidney                                       1
# Toxic effect of lead and its compounds, accidental, sequela          1
# Name: DIAG_001_DIAG_DESC, Length: 8073, dtype: int64
#
#
# Column: DIAG_002_DIAG_DESC
# Nausea with vomiting, unspecified                               112390
# Estrogen receptor positive status [ER+]                          90746
# Essential (primary) hypertension                                 37726
# Estrogen receptor negative status [ER-]                          36835
# Secondary malig neoplasm of liver and intrahepatic bile duct     21763
#                                                                  ...
# Chronic drug-induced interstitial lung disorders                     1
# Other chondrocalcinosis, unspecified knee                            1
# Stable burst fx T9-T10 vertebra, subs for fx w routn heal            1
# Nondisp avuls fracture (chip fracture) of left talus, init           1
# Basal cell carcinoma of skin of unspecified parts of face            1
# Name: DIAG_002_DIAG_DESC, Length: 6874, dtype: int64
#
#
# Column: DIAG_003_DIAG_DESC
# Nausea with vomiting, unspecified                               84552
# Adverse effect of antineoplastic and immunosup drugs, init      54012
# Agranulocytosis secondary to cancer chemotherapy                44784
# Essential (primary) hypertension                                31860
# Estrogen receptor positive status [ER+]                         22385
#                                                                 ...
# Nexdtve age-related mclr degn, bilateral, stage unspecified         1
# Abnormal cytological findings in specimens from oth org/tiss        1
# Malposition of uterus                                               1
# Short stature (child)                                               1
# Toxic effect of lead and its compounds, accidental, sequela         1
# Name: DIAG_003_DIAG_DESC, Length: 5715, dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
claims.describe()
# Out:
#            DRG   C_UTIL_CT   c_allowed  days_since_earliest_dt  \
# count 4891.000 2517387.000 2517387.000             2517387.000
# mean   428.134       8.297     269.178                 704.547
# std    251.810      21.382    1883.226                 822.841
# min      1.000      -1.001      -0.020                -366.000
# 25%    196.000       0.000       3.321                  91.000
# 50%    336.000       1.000      23.200                 383.000
# 75%    584.000       1.006     106.049                1127.000
# max    989.000     365.710  569337.035                3819.000
#
#        provider_number
# count      1649058.000
# mean          3130.784
# std           1923.689
# min              1.000
# 25%           2236.000
# 50%           2244.000
# 75%           2727.000
# max           8220.000

# %%
# create a PK for claims
claims = claims.reset_index(drop=True)
claims["claim_id"] = claims.index.astype(str)
claims.head()
# Out:
#   PRI_DIAG_CD ADM_DIAG_CD DIAG_CD_001 DIAG_CD_002 DIAG_CD_003  HCPCS  DRG  \
# 0        J431         NaN         NaN         NaN         NaN  94727  NaN
# 1        J431         NaN         NaN         NaN         NaN  94060  NaN
# 2        J431         NaN         NaN         NaN         NaN  94060  NaN
# 3        J431         NaN         NaN         NaN         NaN  94726  NaN
# 4        J431         NaN         NaN         NaN         NaN  94729  NaN
#
#      Med_Cost_Category NDC_CD DRUG_NM  ...  ROUTE DESCRIPTION  \
# 0  Prof PCP Procedures    NaN     NaN  ...                NaN
# 1  Prof PCP Procedures    NaN     NaN  ...                NaN
# 2             OP Other    NaN     NaN  ...                NaN
# 3             OP Other    NaN     NaN  ...                NaN
# 4             OP Other    NaN     NaN  ...                NaN
#
#    STRENGTH DESCRIPTION                     PROC_DESC             DIAG_DESC  \
# 0                   NaN     Pulm function test by gas  Panlobular emphysema
# 1                   NaN        Evaluation of wheezing  Panlobular emphysema
# 2                   NaN        Evaluation of wheezing  Panlobular emphysema
# 3                   NaN  Pulm funct tst plethysmograp  Panlobular emphysema
# 4                   NaN   Co/membane diffuse capacity  Panlobular emphysema
#
#    DRG_DESC ADM_DIAG_DESC DIAG_001_DIAG_DESC DIAG_002_DIAG_DESC  \
# 0       NaN           NaN                NaN                NaN
# 1       NaN           NaN                NaN                NaN
# 2       NaN           NaN                NaN                NaN
# 3       NaN           NaN                NaN                NaN
# 4       NaN           NaN                NaN                NaN
#
#   DIAG_003_DIAG_DESC claim_id
# 0                NaN        0
# 1                NaN        1
# 2                NaN        2
# 3                NaN        3
# 4                NaN        4
#
# [5 rows x 25 columns]

# %%
# number of unique providers per member number
provider_count = (
    claims.groupby("member_number")["provider_number"]
    .nunique()
    .reset_index(name="num_providers")
)

# %%
provider_spend = (
    claims.groupby(["member_number", "provider_number"])["c_allowed"]
    .sum()
    .reset_index()
)

# %%
top_provider_share = (
    provider_spend.sort_values(["member_number", "c_allowed"], ascending=False)
    .groupby("member_number")
    .first()["c_allowed"]
)

# %%
total_spend = claims.groupby("member_number")["c_allowed"].sum()

provider_concentration = (top_provider_share / total_spend).reset_index(name="top_provider_share")

provider_concentration.sort_values("top_provider_share", ascending=False)
# Out:
#      member_number  top_provider_share
# 2815          C818               1.000
# 1913          B915               0.992
# 498           A499               0.985
# 1259          B261               0.982
# 748           A749               0.971
# ...            ...                 ...
# 1932          B934                 NaN
# 2670          C673                 NaN
# 2750          C753                 NaN
# 3210          D214                 NaN
# 3553          D557                 NaN
#
# [3657 rows x 2 columns]

# %% [markdown]
# ### Initial Join

# %%
# patient-level aggregation of cost, utilization, and time since first claim
patient_level = claims.groupby("member_number").agg({
        "c_allowed": "sum",
        "C_UTIL_CT": "sum",
        "days_since_earliest_dt": ["min", "max"]
    })

# rename columns
patient_level.columns = [
    "total_cost",
    "total_util",
    "first_claim_day",
    "last_claim_day"
]

# time since first claim
patient_level["time_since_first_claim"] = patient_level["last_claim_day"] - patient_level["first_claim_day"]

patient_level
# Out:
#                total_cost  total_util  first_claim_day  last_claim_day  \
# member_number
# A001            34347.750    3635.000             -364               1
# A002           510592.723    4924.409             -357            1248
# A003           292610.070   23653.000             -364            1580
# A004             1570.131     891.586              -14             195
# A005           205847.260    7610.728             -364            1026
# ...                   ...         ...              ...             ...
# D656              631.394     157.597              -41               2
# D657            58470.372    1190.183               -1             111
# D658            20523.931      95.685                0              97
# D659            57216.047     391.366                0             104
# D660             8142.279      10.616                0              65
#
#                time_since_first_claim
# member_number
# A001                              365
# A002                             1605
# A003                             1944
# A004                              209
# A005                             1390
# ...                               ...
# D656                               43
# D657                              112
# D658                               97
# D659                              104
# D660                               65
#
# [3657 rows x 5 columns]

# %%
# category-level spend per member
category_spend = claims.groupby(["member_number", "Med_Cost_Category"])["c_allowed"].sum().unstack(fill_value=0).reset_index()

category_spend
# Out:
# Med_Cost_Category member_number  IP Behavioral Health  IP Maternity  \
# 0                          A001                 0.000         0.000
# 1                          A002             11121.566         0.000
# 2                          A003                 0.000         0.000
# 3                          A004                 0.000         0.000
# 4                          A005                 0.000         0.000
# ...                         ...                   ...           ...
# 3652                       D656                 0.000         0.000
# 3653                       D657                 0.000         0.000
# 3654                       D658                 0.000         0.000
# 3655                       D659                 0.000         0.000
# 3656                       D660                 0.000         0.000
#
# Med_Cost_Category  IP Medical    IP SNF  IP Surgical  OP Behavioral Health  \
# 0                    6479.460     0.000        0.000              1469.230
# 1                   42436.994     0.000    92381.064                 0.000
# 2                       0.000     0.000        0.000                 0.000
# 3                       0.000     0.000        0.000                 0.000
# 4                       0.000 16040.090    65092.535                 0.000
# ...                       ...       ...          ...                   ...
# 3652                    0.000     0.000        0.000                 0.000
# 3653                    0.000     0.000    14477.743                 0.000
# 3654                    0.000     0.000    10330.222                 0.000
# 3655                    0.000     0.000        0.000                 0.000
# 3656                    0.000     0.000        0.000                 0.000
#
# Med_Cost_Category     OP ER  OP Observation  OP Other  ...  OP Pharmacy  \
# 0                     0.000           0.000  2577.270  ...        0.000
# 1                 10452.507        8916.282  7333.956  ...   120121.367
# 2                   684.030           0.000  7247.420  ...    72966.420
# 3                     0.000           0.000   274.128  ...        0.000
# 4                  4948.763       16478.207   162.990  ...        0.000
# ...                     ...             ...       ...  ...          ...
# 3652                  0.000           0.000   123.241  ...        0.000
# 3653               1046.425           0.000   868.693  ...     3092.019
# 3654                  0.000           0.000   156.314  ...      152.278
# 3655               1135.433           0.000  1062.573  ...        0.000
# 3656                  0.000           0.000     0.000  ...     7041.425
#
# Med_Cost_Category  OP Radiology  OP Surgery  PDN/Home Health  \
# 0                       228.570    5024.840            0.000
# 1                     11498.224  124509.431         1686.759
# 2                     26884.950   39724.130          979.650
# 3                       215.830       0.000            0.000
# 4                         0.000       0.000        46910.494
# ...                         ...         ...              ...
# 3652                      0.000       0.000            0.000
# 3653                  24096.903    3270.509            0.000
# 3654                      0.000    2379.597            0.000
# 3655                      0.000   41631.642            0.000
# 3656                    272.565       0.000            0.000
#
# Med_Cost_Category  Prof Invisible Prov Procedures  Prof Other  \
# 0                                        2132.430     383.600
# 1                                       20627.390    3210.378
# 2                                        7325.020    1043.210
# 3                                          68.180       0.000
# 4                                        8202.642   16798.127
# ...                                           ...         ...
# 3652                                        0.000       0.000
# 3653                                     2857.881     396.204
# 3654                                     1786.287       0.000
# 3655                                     3446.694      79.361
# 3656                                       12.541      67.548
#
# Med_Cost_Category  Prof PCP Procedures  Prof Specialist Procedures         RX  \
# 0                             1753.840                    5017.300   8469.430
# 1                             7274.885                   36204.057  10207.797
# 2                             2641.830                   25655.400 106422.650
# 3                                0.000                     812.753    199.240
# 4                             8305.031                   10868.237  11823.801
# ...                                ...                         ...        ...
# 3652                           253.580                     120.612     30.334
# 3653                          1300.818                    4930.634   1820.672
# 3654                           472.021                    4297.571    837.083
# 3655                           196.071                    9523.914    110.582
# 3656                             0.000                     558.362      0.000
#
# Med_Cost_Category  Unknown
# 0                    0.000
# 1                    0.000
# 2                    0.000
# 3                    0.000
# 4                    0.000
# ...                    ...
# 3652                 0.000
# 3653                 0.000
# 3654                 0.000
# 3655                 0.000
# 3656                 0.000
#
# [3657 rows x 21 columns]

# %%
merged_df = patient_level.merge(category_spend, on="member_number", how="left").merge(staging, on="member_number", how="left")

merged_df.drop(columns=["has_path", "has_clin"], inplace=True)

merged_df
# Out:
#      member_number  total_cost  total_util  first_claim_day  last_claim_day  \
# 0             A001   34347.750    3635.000             -364               1
# 1             A002  510592.723    4924.409             -357            1248
# 2             A003  292610.070   23653.000             -364            1580
# 3             A004    1570.131     891.586              -14             195
# 4             A005  205847.260    7610.728             -364            1026
# ...            ...         ...         ...              ...             ...
# 3652          D656     631.394     157.597              -41               2
# 3653          D657   58470.372    1190.183               -1             111
# 3654          D658   20523.931      95.685                0              97
# 3655          D659   57216.047     391.366                0             104
# 3656          D660    8142.279      10.616                0              65
#
#       time_since_first_claim  IP Behavioral Health  IP Maternity  IP Medical  \
# 0                        365                 0.000         0.000    6479.460
# 1                       1605             11121.566         0.000   42436.994
# 2                       1944                 0.000         0.000       0.000
# 3                        209                 0.000         0.000       0.000
# 4                       1390                 0.000         0.000       0.000
# ...                      ...                   ...           ...         ...
# 3652                      43                 0.000         0.000       0.000
# 3653                     112                 0.000         0.000       0.000
# 3654                      97                 0.000         0.000       0.000
# 3655                     104                 0.000         0.000       0.000
# 3656                      65                 0.000         0.000       0.000
#
#         IP SNF  ...         RX  Unknown  ICD10_CODE  \
# 0        0.000  ...   8469.430    0.000     C50.111
# 1        0.000  ...  10207.797    0.000     C50.412
# 2        0.000  ... 106422.650    0.000     C50.412
# 3        0.000  ...    199.240    0.000     C50.812
# 4    16040.090  ...  11823.801    0.000       C18.7
# ...        ...  ...        ...      ...         ...
# 3652     0.000  ...     30.334    0.000       C18.4
# 3653     0.000  ...   1820.672    0.000      C34.12
# 3654     0.000  ...    837.083    0.000       C18.7
# 3655     0.000  ...    110.582    0.000     C50.511
# 3656     0.000  ...      0.000    0.000     C50.411
#
#       MOST_RECENT_PATH_STAGE_DT  MOST_RECENT_CLINICAL_STAGE_DT  \
# 0                       203.000                         25.000
# 1                       110.000                            NaN
# 2                       755.000                            NaN
# 3                           NaN                      -2843.000
# 4                        80.000                            NaN
# ...                         ...                            ...
# 3652                   -183.000                            NaN
# 3653                        NaN                          4.000
# 3654                     34.000                            NaN
# 3655                     39.000                            NaN
# 3656                        NaN                      -2049.000
#
#       PATHOLOGIC_STAGE_GROUP  CLINICAL_STAGE_GROUP  ICD10_group  cancer_type  \
# 0                  Stage IIA            Stage IIIB          C50       breast
# 1                   Stage IA                   NaN          C50       breast
# 2                   Stage IA                   NaN          C50       breast
# 3                        NaN             Stage IIA          C50       breast
# 4                    Stage I                   NaN          C18   colorectal
# ...                      ...                   ...          ...          ...
# 3652               Stage IIA                   NaN          C18   colorectal
# 3653                     NaN            Stage IIIA          C34         lung
# 3654               Stage IIA                   NaN          C18   colorectal
# 3655                Stage IA                   NaN          C50       breast
# 3656                     NaN             Stage IIA          C50       breast
#
#       FINAL_STAGE
# 0       Stage IIA
# 1        Stage IA
# 2        Stage IA
# 3       Stage IIA
# 4         Stage I
# ...           ...
# 3652    Stage IIA
# 3653   Stage IIIA
# 3654    Stage IIA
# 3655     Stage IA
# 3656    Stage IIA
#
# [3657 rows x 34 columns]

# %%
# member number showing up multiple times in merged_df, see those members in a table
merged_df["member_number"].value_counts().sort_values(ascending=False)
# Out:
# A001    1
# A030    1
# A028    1
# A014    1
# A003    1
#        ..
# D655    1
# D656    1
# D657    1
# D658    1
# D660    1
# Name: member_number, Length: 3657, dtype: int64

# %%
merged_df.columns
# Out:
# Index(['member_number', 'total_cost', 'total_util', 'first_claim_day',
#        'last_claim_day', 'time_since_first_claim', 'IP Behavioral Health',
#        'IP Maternity', 'IP Medical', 'IP SNF', 'IP Surgical',
#        'OP Behavioral Health', 'OP ER', 'OP Observation', 'OP Other',
#        'OP Path/Lab', 'OP Pharmacy', 'OP Radiology', 'OP Surgery',
#        'PDN/Home Health', 'Prof Invisible Prov Procedures', 'Prof Other',
#        'Prof PCP Procedures', 'Prof Specialist Procedures', 'RX', 'Unknown',
#        'ICD10_CODE', 'MOST_RECENT_PATH_STAGE_DT',
#        'MOST_RECENT_CLINICAL_STAGE_DT', 'PATHOLOGIC_STAGE_GROUP',
#        'CLINICAL_STAGE_GROUP', 'ICD10_group', 'cancer_type', 'FINAL_STAGE'],
#       dtype='object')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3657 entries, 0 to 3656
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   member_number                   3657 non-null   object
#  1   total_cost                      3657 non-null   float64
#  2   total_util                      3657 non-null   float64
#  3   first_claim_day                 3657 non-null   int64
#  4   last_claim_day                  3657 non-null   int64
#  5   time_since_first_claim          3657 non-null   int64
#  6   IP Behavioral Health            3657 non-null   float64
#  7   IP Maternity                    3657 non-null   float64
#  8   IP Medical                      3657 non-null   float64
#  9   IP SNF                          3657 non-null   float64
#  10  IP Surgical                     3657 non-null   float64
#  11  OP Behavioral Health            3657 non-null   float64
#  12  OP ER                           3657 non-null   float64
#  13  OP Observation                  3657 non-null   float64
#  14  OP Other                        3657 non-null   float64
#  15  OP Path/Lab                     3657 non-null   float64
#  16  OP Pharmacy                     3657 non-null   float64
#  17  OP Radiology                    3657 non-null   float64
#  18  OP Surgery                      3657 non-null   float64
#  19  PDN/Home Health                 3657 non-null   float64
#  20  Prof Invisible Prov Procedures  3657 non-null   float64
#  21  Prof Other                      3657 non-null   float64
#  22  Prof PCP Procedures             3657 non-null   float64
#  23  Prof Specialist Procedures      3657 non-null   float64
#  24  RX                              3657 non-null   float64
#  25  Unknown                         3657 non-null   float64
#  26  ICD10_CODE                      3550 non-null   object
#  27  MOST_RECENT_PATH_STAGE_DT       1810 non-null   float64
#  28  MOST_RECENT_CLINICAL_STAGE_DT   2172 non-null   float64
#  29  PATHOLOGIC_STAGE_GROUP          1755 non-null   object
#  30  CLINICAL_STAGE_GROUP            2085 non-null   object
#  31  ICD10_group                     3550 non-null   object
#  32  cancer_type                     3550 non-null   object
#  33  FINAL_STAGE                     3550 non-null   object
# dtypes: float64(24), int64(3), object(7)
# memory usage: 1000.0+ KB

# %%
# export merged_df to csv
merged_df.to_csv("merged_staging_claims_patient_level.csv", index=False)
